# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import seaborn as sns

# %%
#create a dataframe from each excel sheet.

filepath = "Cleaned Files/Copy of mort_cleaned.xlsx"

xls = pd.ExcelFile(filepath)
df_HIV_AIDS_tuberculosis = pd.read_excel(xls, 'HIV-AIDS & tuberculosis')
df_Diarrhea_lower_respiratory = pd.read_excel(xls,'Diarrhea, lower respiratory')
df_Neglected_tropical_diseases = pd.read_excel(xls,'Neglected tropical diseases')
df_Maternal_disorders = pd.read_excel(xls,'Maternal disorders')
df_Neonatal_disorders = pd.read_excel(xls,'Neonatal disorders')
df_Nutritional_deficiencies = pd.read_excel(xls, 'Nutritional deficiencies')
df_Other_communicable_maternal  = pd.read_excel(xls,'Other communicable_maternal')
df_Neoplasms = pd.read_excel(xls,'Neoplasms')
df_Cardiovascular_diseases = pd.read_excel(xls,'Cardiovascular diseases')
df_Chronic_respiratory_diseases = pd.read_excel(xls,'Chronic respiratory diseases')
df_Cirrhosis_other_chronic  = pd.read_excel(xls,'Cirrhosis & other chronic ')
df_Digestive_diseases = pd.read_excel(xls, 'Digestive diseases')
df_Neurological_disorders  = pd.read_excel(xls,'Neurological disorders')
df_Mental_substance_use  = pd.read_excel(xls,'Mental & substance use ')
df_Diabetes_urogenital_blood = pd.read_excel(xls,'Diabetes_urogenital_blood')
df_Musculoskeletal_disorders = pd.read_excel(xls,'Musculoskeletal disorders')
df_Other_non_communicable   = pd.read_excel(xls,'Other non-communicable ')
df_Transport_injuries = pd.read_excel(xls, 'Transport injuries')
df_Unintentional_injuries  = pd.read_excel(xls,'Unintentional injuries')
df_Self_harm_interpersonal   = pd.read_excel(xls,'Self-harm & interpersonal ')
df_Forces_of_nature_war_legal  = pd.read_excel(xls,'Forces of nature, war, & legal ')

# %%
df_Diabetes_urogenital_blood.head()
# Out:
#                   Location    FIPS Mortality Rate, 1980*  \
# 0            United States     NaN  46.20 (44.96, 47.56)
# 1                  Alabama     1.0  57.83 (56.10, 59.56)
# 2  Autauga County, Alabama  1001.0  54.08 (50.06, 58.40)
# 3  Baldwin County, Alabama  1003.0  46.30 (43.40, 49.00)
# 4  Barbour County, Alabama  1005.0  64.02 (59.77, 68.43)
#
#   Mortality Rate, 1985* Mortality Rate, 1990* Mortality Rate, 1995*  \
# 0  47.35 (46.35, 48.43)  49.11 (48.05, 50.17)  53.58 (52.41, 54.81)
# 1  58.79 (57.48, 60.19)  61.83 (60.38, 63.15)  68.46 (66.81, 70.19)
# 2  56.46 (52.61, 60.41)  60.00 (56.64, 63.59)  66.41 (62.87, 70.13)
# 3  44.87 (42.60, 47.33)  46.33 (44.08, 48.61)  50.03 (47.63, 52.60)
# 4  63.88 (60.01, 67.75)  64.93 (61.36, 68.17)  70.88 (67.30, 74.81)
#
#   Mortality Rate, 2000* Mortality Rate, 2005* Mortality Rate, 2010*  \
# 0  58.01 (56.75, 59.31)  59.04 (57.72, 60.44)  55.70 (54.34, 57.00)
# 1  74.81 (73.11, 76.57)  76.62 (74.79, 78.59)  72.34 (70.54, 74.13)
# ...

# %%
#plot histogram to see distribution
plt.figure(figsize =(10,5))
df_Diabetes_urogenital_blood.plot(kind= "hist")

# %%
#df= df_Diabetes_urogenital_blood(["Year", "State"], axis =1)

# %%
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1980*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1985*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1990*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1995*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2000*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2005*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2010*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2014*": "Mortality Rate"}, inplace = True)

# %%
#df_Diabetes_urogenital_blood.plot(kind= "scatter" , x= "Mortality Rate", y = "Location")
#plt.show()

# %%
filepath2 = "Cleaned Files/NIH Data Alcohol Consumption.csv"
filepath3 = "Cleaned Files/NIH Data FIPS.csv"
filepath4 = "Cleaned Files/NIH Beverage Codes.csv"

df_nih = pd.read_csv(filepath2)
df_beverage_codes = pd.read_csv(filepath4)
df_fips_codes = pd.read_csv(filepath3)

# %%
df_nih.head()
# Out:
#    Year  FIPS  Type of beverage Gallons of beverage  Gallons of ethanol  \
# 0  1970     1                 1             3863000             1738350
# 1  1970     1                 2             1412000              225920
# 2  1970     1                 3            33098000             1489410
# 3  1970     1                 4                   .             3453680
# 4  1970     2                 1              945000              425250
#
#    Population (14 and older)  Gallons of ethanol per capita age 14 and older  \
# 0                    2499000                                            6956
# 1                    2499000                                             904
# 2                    2499000                                            5960
# 3                    2499000                                           13820
# 4                     205000                                           20744
#
#    Decile for per capita consumption age 14 and older  \
# ...

# %%
df_nih_merged = pd.merge(df_nih, df_beverage_codes, how="left", left_on = 'Type of beverage', right_on = 'Beverage ID')
df_nih_merged = pd.merge(df_nih_merged, df_fips_codes, how="left", left_on = 'FIPS', right_on = 'FIPS')

# %%
df_nih_merged.head()
# Out:
#    Year  FIPS  Type of beverage Gallons of beverage  Gallons of ethanol  \
# 0  1970     1                 1             3863000             1738350
# 1  1970     1                 2             1412000              225920
# 2  1970     1                 3            33098000             1489410
# 3  1970     1                 4                   .             3453680
# 4  1970     2                 1              945000              425250
#
#    Population (14 and older)  Gallons of ethanol per capita age 14 and older  \
# 0                    2499000                                            6956
# 1                    2499000                                             904
# 2                    2499000                                            5960
# 3                    2499000                                           13820
# 4                     205000                                           20744
#
#    Decile for per capita consumption age 14 and older  \
# ...

# %%
# Create subsets for year

nih_1980 = df_nih_merged.loc[(df_nih_merged['Year'] == 1980) & (df_nih_merged['FIPS'] < 60)]
nih_1985 = df_nih_merged.loc[(df_nih_merged['Year'] == 1985) & (df_nih_merged['FIPS'] < 60)]
nih_1990 = df_nih_merged.loc[(df_nih_merged['Year'] == 1990) & (df_nih_merged['FIPS'] < 60)]
nih_1995 = df_nih_merged.loc[(df_nih_merged['Year'] == 1995) & (df_nih_merged['FIPS'] < 60)]
nih_2000 = df_nih_merged.loc[(df_nih_merged['Year'] == 2000) & (df_nih_merged['FIPS'] < 60)]
nih_2005 = df_nih_merged.loc[(df_nih_merged['Year'] == 2005) & (df_nih_merged['FIPS'] < 60)]
nih_2010 = df_nih_merged.loc[(df_nih_merged['Year'] == 2010) & (df_nih_merged['FIPS'] < 60)]
nih_2014 = df_nih_merged.loc[(df_nih_merged['Year'] == 2014) & (df_nih_merged['FIPS'] < 60)]

# %%
# Get States Data from Diabetes DataFrame
df_Diabetes_urogenital_blood = df_Diabetes_urogenital_blood.loc[df_Diabetes_urogenital_blood['FIPS'] < 60]

# %%
df_Diabetes_urogenital_blood.head()
# Out:
#        Location  FIPS        Mortality Rate        Mortality Rate  \
# 1       Alabama   1.0  57.83 (56.10, 59.56)  58.79 (57.48, 60.19)
# 69       Alaska   2.0  40.66 (38.31, 43.17)  40.23 (38.32, 42.21)
# 99      Arizona   4.0  38.06 (36.89, 39.38)  38.76 (37.68, 39.89)
# 115    Arkansas   5.0  49.02 (47.62, 50.49)  50.10 (49.05, 51.24)
# 191  California   6.0  37.01 (35.95, 38.16)  38.08 (37.24, 38.96)
#
#            Mortality Rate        Mortality Rate        Mortality Rate  \
# 1    61.83 (60.38, 63.15)  68.46 (66.81, 70.19)  74.81 (73.11, 76.57)
# 69   41.71 (39.90, 43.46)  44.76 (43.02, 46.72)  49.50 (47.73, 51.62)
# 99   38.82 (37.74, 39.83)  42.76 (41.61, 43.89)  47.33 (46.14, 48.57)
# 115  53.24 (52.12, 54.35)  59.17 (57.96, 60.52)  65.79 (64.37, 67.19)
# 191  39.09 (38.21, 39.97)  43.54 (42.55, 44.58)  47.83 (46.80, 48.88)
#
#            Mortality Rate        Mortality Rate        Mortality Rate  \
# 1    76.62 (74.79, 78.59)  72.34 (70.54, 74.13)  70.81 (68.84, 72.75)
# ...

# %%
#New Dataframe
nih_1980_merged_diabetes = pd.merge(nih_1980, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_1985_merged_diabetes = pd.merge(nih_1985, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_1990_merged_diabetes = pd.merge(nih_1990, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_1995_merged_diabetes = pd.merge(nih_1995, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_2000_merged_diabetes = pd.merge(nih_2000, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_2005_merged_diabetes = pd.merge(nih_2005, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_2010_merged_diabetes = pd.merge(nih_2010, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )
nih_2014_merged_diabetes = pd.merge(nih_2014, df_Diabetes_urogenital_blood, how = 'left', left_on = 'State', right_on = 'Location' )

# %%
# Grab only needed columns (don't forget to change year number in Mortality Rate column)
#nih_1980_merged_diabetes = nih_1980_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 1980*','Location']]
#nih_1985_merged_diabetes = nih_1985_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 1985*','Location']]
#nih_1990_merged_diabetes = nih_1990_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 1990*','Location']]
#nih_1995_merged_diabetes = nih_1995_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 1995*','Location']]
#nih_2000_merged_diabetes = nih_2000_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 2000*','Location']]
#nih_2005_merged_diabetes = nih_2005_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 2005*','Location']]
#nih_2010_merged_diabetes = nih_2010_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 2010*','Location']]
#nih_2014_merged_diabetes = nih_2014_merged_diabetes[['Year','FIPS_x','Type of beverage', 'Gallons of ethanol per capita age 21 and older','Mortality Rate, 2014*','Location']]

# %%
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1980*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1985*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1990*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 1995*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2000*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2005*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2010*": "Mortality Rate"}, inplace = True)
df_Diabetes_urogenital_blood.rename(columns={"Mortality Rate, 2014*": "Mortality Rate"}, inplace = True)
# Out:
# C:\Users\adewale\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# Concatenate all year dataframes
frames_diabetes = [nih_1980_merged_diabetes, 
                    nih_1985_merged_diabetes,
                    nih_1990_merged_diabetes,
                    nih_1995_merged_diabetes,
                    nih_2000_merged_diabetes,
                    nih_2005_merged_diabetes,
                    nih_2010_merged_diabetes,
                    nih_2014_merged_diabetes]

df_concat_diabetes = pd.concat(frames_diabetes)

df_concat_diabetes
# Out:
#      Year  FIPS_x  Type of beverage Gallons of beverage  Gallons of ethanol  \
# 0    1980       1                 1             5475000             2250225
# 1    1980       1                 2             3816000              492264
# 2    1980       1                 3            64209000             2889405
# 3    1980       1                 4                   .             5631894
# 4    1980       2                 1             1240000              509640
# ..    ...     ...               ...                 ...                 ...
# 199  2014      55                 4                   .            14151977
# 200  2014      56                 1             1339225              550421
# 201  2014      56                 2             1130211              145797
# 202  2014      56                 3            13231717              595427
# 203  2014      56                 4                   .             1291646
#
#      Population (14 and older)  \
# ...

# %%
df_concat_diabetes= pd.merge(df_concat_diabetes,df_beverage_codes, how='left', left_on ='Type of beverage', right_on = 'Beverage ID')

# %%
df_concat_diabetes
# Out:
#       Year  FIPS_x  Type of beverage Gallons of beverage  Gallons of ethanol  \
# 0     1980       1                 1             5475000             2250225
# 1     1980       1                 2             3816000              492264
# 2     1980       1                 3            64209000             2889405
# 3     1980       1                 4                   .             5631894
# 4     1980       2                 1             1240000              509640
# ...    ...     ...               ...                 ...                 ...
# 1627  2014      55                 4                   .            14151977
# 1628  2014      56                 1             1339225              550421
# 1629  2014      56                 2             1130211              145797
# 1630  2014      56                 3            13231717              595427
# 1631  2014      56                 4                   .             1291646
#
#       Population (14 and older)  \
# ...

# %%
# Isolate rows for all beverages
df_concat_diabetes4 = df_concat_diabetes.loc[df_concat_diabetes['Type of beverage'] == 4]
df_concat_diabetes1 = df_concat_diabetes.loc[df_concat_diabetes['Type of beverage'] == 1]
df_concat_diabetes2 = df_concat_diabetes.loc[df_concat_diabetes['Type of beverage'] == 2]
df_concat_diabetes3 = df_concat_diabetes.loc[df_concat_diabetes['Type of beverage'] == 3]

# %%
df_concat_diabetes4.describe()
# Out:
#              Year      FIPS_x  Type of beverage  Gallons of ethanol  \
# count   408.00000  408.000000             408.0        4.080000e+02
# mean   1997.37500   28.960784               4.0        1.016332e+07
# std      11.28257   15.696083               0.0        1.158144e+07
# min    1980.00000    1.000000               4.0        8.771990e+05
# 25%    1988.75000   16.000000               4.0        2.770640e+06
# 50%    1997.50000   29.000000               4.0        6.585582e+06
# 75%    2006.25000   42.000000               4.0        1.200707e+07
# max    2014.00000   56.000000               4.0        7.346280e+07
#
#        Population (14 and older)  \
# count               4.080000e+02
# mean                4.312414e+06
# std                 4.814766e+06
# min                 3.031640e+05
# 25%                 1.117123e+06
# 50%                 2.940844e+06
# 75%                 5.066972e+06
# max                 3.153279e+07
#
# ...

# %%
# Remove nulls

df_concat_diabetes4.dropna(inplace=True)
df_concat_diabetes1.dropna(inplace=True)
df_concat_diabetes2.dropna(inplace=True)
df_concat_diabetes3.dropna(inplace=True)
# Out:
# C:\Users\adewale\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\adewale\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\adewale\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_concat_diabetes4.describe()
# Out:
#               Year      FIPS_x  Type of beverage  Gallons of ethanol  \
# count   392.000000  392.000000             392.0        3.920000e+02
# mean   1997.375000   29.244898               4.0        1.044824e+07
# std      11.283135   15.793463               0.0        1.172567e+07
# min    1980.000000    1.000000               4.0        8.771990e+05
# 25%    1988.750000   17.000000               4.0        2.790826e+06
# 50%    1997.500000   29.000000               4.0        7.044824e+06
# 75%    2006.250000   42.000000               4.0        1.234044e+07
# max    2014.000000   56.000000               4.0        7.346280e+07
#
#        Population (14 and older)  \
# count               3.920000e+02
# mean                4.458371e+06
# std                 4.856293e+06
# min                 3.031640e+05
# 25%                 1.244088e+06
# 50%                 3.092288e+06
# 75%                 5.188990e+06
# max                 3.153279e+07
#
# ...

# %%
df_concat_diabetes2.describe()
# Out:
#               Year      FIPS_x  Type of beverage  Gallons of ethanol  \
# count   392.000000  392.000000             392.0        3.920000e+02
# mean   1997.375000   29.244898               2.0        1.568944e+06
# std      11.283135   15.793463               0.0        2.416647e+06
# min    1980.000000    1.000000               2.0        6.021300e+04
# 25%    1988.750000   17.000000               2.0        3.142462e+05
# 50%    1997.500000   29.000000               2.0        8.155745e+05
# 75%    2006.250000   42.000000               2.0        1.817387e+06
# max    2014.000000   56.000000               2.0        1.888116e+07
#
#        Population (14 and older)  \
# count               3.920000e+02
# mean                4.458371e+06
# std                 4.856293e+06
# min                 3.031640e+05
# 25%                 1.244088e+06
# 50%                 3.092288e+06
# 75%                 5.188990e+06
# max                 3.153279e+07
#
# ...

# %%
x_values4 = df_concat_diabetes4['Gallons of ethanol per capita age 21 and older']
y_values4 = df_concat_diabetes4['Mortality Rate']

x_values1 = df_concat_diabetes1['Gallons of ethanol per capita age 21 and older']
y_values1 = df_concat_diabetes1['Mortality Rate']

x_values2 = df_concat_diabetes2['Gallons of ethanol per capita age 21 and older']
y_values2 = df_concat_diabetes2['Mortality Rate']

x_values3 = df_concat_diabetes3['Gallons of ethanol per capita age 21 and older']
y_values3 = df_concat_diabetes3['Mortality Rate']

# %%
plt.figure(figsize=(9,8))
cor = df_concat_diabetes4.corr()
sns.heatmap(cor, annot = True, cmap=plt.cm.RdYlBu)
plt.show()
